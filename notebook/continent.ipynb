# %%
import session_info
import geopandas as gpd
import matplotlib.pyplot as plt
import pathlib
import os

# %%
print(gpd.datasets.available)
# Out:
# ['naturalearth_cities', 'naturalearth_lowres', 'nybb']

# %%
gdf = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# Out:
# C:\Users\rmtum\AppData\Local\Temp\ipykernel_12372\2529238599.py:1: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   gdf = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
gdf.head()
# Out:
#        pop_est      continent                      name iso_a3  gdp_md_est  \
# 0     889953.0        Oceania                      Fiji    FJI        5496
# 1   58005463.0         Africa                  Tanzania    TZA       63177
# 2     603253.0         Africa                 W. Sahara    ESH         907
# 3   37589262.0  North America                    Canada    CAN     1736425
# 4  328239523.0  North America  United States of America    USA    21433226
#
#                                             geometry
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...

# %%
f,ax = plt.subplots(1,1,figsize=(10,6))
gdf.plot(ax=ax, column='continent', cmap='tab20', edgecolor='k', linewidth=.7)
f.patch.set_facecolor('black')

# Set the axes background color to black
ax.set_facecolor('black')
plt.axis('off')
plt.tight_layout()
# plt.show()


# saving the map
NOTEBOOK_PATH = pathlib.Path().resolve()
Map = NOTEBOOK_PATH / "Map" 

figure_path = os.path.join(Map, "continents.png")
plt.tight_layout()
plt.savefig(figure_path)
